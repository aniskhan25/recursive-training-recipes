# %% [markdown]
# # 08 Hybrid Teacher + Threshold
#
# ## Concept
# Hybrid combines:
# - teacher smoothing (from Mean Teacher)
# - confidence filtering (from thresholded pseudo-labeling)

# %% [markdown]
# ## Why This Method Exists
# Each stabilizer solves a different problem:
# - teacher reduces noisy targets
# - threshold blocks low-confidence pseudo-labels

# %% [markdown]
# ## Algorithm Intuition
# We compare three methods on the same split:
# 1. Self-training
# 2. Mean Teacher
# 3. Hybrid

# %% [markdown]
# ## Before You Run
# This notebook defaults to `FAST_DEV_RUN=True` so beginners can run it quickly.

# %% [markdown]
# ## Step 1: Imports

# %%
from pathlib import Path
import sys
import torch
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent / 'src'))

from utils.seed import set_seed
from data.mnist import get_mnist_ssl_twoview
from data.cifar10 import get_cifar10_ssl_twoview
from models.small_cnn import SmallCNN
from models.resnet18 import build_resnet18
from methods.self_training import run_self_training
from methods.mean_teacher import run_mean_teacher
from methods.hybrid_teacher_threshold import run_hybrid

# %% [markdown]
# ## Step 2: Shared Configuration

# %%
set_seed(42)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FAST_DEV_RUN = True

if FAST_DEV_RUN:
    loaders = get_mnist_ssl_twoview('data', labeled_per_class=50, batch_size=128, num_workers=2, seed=42)
    build = SmallCNN
    epochs = 6
    rounds = 6
    tau = 0.95
    lambda_u = 1.0
    ema_decay = 0.99
    warmup = 2
else:
    loaders = get_cifar10_ssl_twoview('data', labeled_per_class=40, batch_size=128, num_workers=2, seed=42)
    build = build_resnet18
    epochs = 20
    rounds = 6
    tau = 0.95
    lambda_u = 10.0
    ema_decay = 0.999
    warmup = 5

config = {
    'fast_dev_run': FAST_DEV_RUN,
    'epochs': epochs,
    'rounds': rounds,
    'tau': tau,
    'lambda_u': lambda_u,
    'ema_decay': ema_decay,
    'warmup': warmup,
}
print(config)
print({'device': str(DEVICE), 'num_labeled': len(loaders.labeled.dataset), 'num_unlabeled': len(loaders.unlabeled.dataset)})

# %% [markdown]
# ## Step 3: Run Self-Training

# %%
st_model = build()
st_opt = torch.optim.SGD(st_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

st = run_self_training(
    st_model,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    st_opt,
    DEVICE,
    rounds=rounds,
    threshold=tau,
    use_soft=False,
    max_unlabeled_per_round=10000,
    use_progress=True,
)

# %% [markdown]
# ## Step 4: Run Mean Teacher

# %%
mt_student = build()
mt_teacher = build()
mt_opt = torch.optim.SGD(mt_student.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

mt = run_mean_teacher(
    mt_student,
    mt_teacher,
    loaders.labeled,
    loaders.unlabeled,
    loaders.test,
    mt_opt,
    DEVICE,
    epochs=epochs,
    ema_decay=ema_decay,
    lambda_u=lambda_u,
    unlabeled_eval=loaders.unlabeled_eval,
    pseudo_threshold=tau,
    warmup_epochs=warmup,
    use_progress=True,
)

# %% [markdown]
# ## Step 5: Run Hybrid

# %%
hy_student = build()
hy_teacher = build()
hy_opt = torch.optim.SGD(hy_student.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

hyb = run_hybrid(
    hy_student,
    hy_teacher,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    hy_opt,
    DEVICE,
    epochs=epochs,
    ema_decay=ema_decay,
    tau=tau,
    lambda_u=lambda_u,
    tau_start=0.70,
    rampup_epochs=warmup,
    use_progress=True,
)

# %% [markdown]
# ## Step 6: Final Snapshot

# %%
summary = {
    'self_training_val_acc': st.history[-1]['val_accuracy'],
    'mean_teacher_val_acc': mt.history[-1]['val_accuracy'],
    'hybrid_val_acc': hyb.history[-1]['val_accuracy'],
    'self_training_accept': st.history[-1]['pseudo_label_fraction'],
    'mean_teacher_accept': mt.history[-1]['pseudo_label_fraction'],
    'hybrid_accept': hyb.history[-1]['pseudo_label_fraction'],
}
summary

# %% [markdown]
# ## Step 7: Diagnostics
# ### Plot A: Accuracy Comparison
# How to read:
# - Compare final value and curve smoothness.

# %%
plt.figure(figsize=(6.2, 3.4))
plt.plot([r['round'] for r in st.history], [r['val_accuracy'] for r in st.history], marker='o', label='self-training')
plt.plot([r['epoch'] for r in mt.history], [r['val_accuracy'] for r in mt.history], marker='o', label='mean teacher')
plt.plot([r['epoch'] for r in hyb.history], [r['val_accuracy'] for r in hyb.history], marker='o', label='hybrid')
plt.title('Accuracy comparison')
plt.xlabel('step')
plt.ylabel('accuracy')
plt.ylim(0, 1)
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Plot B: Pseudo-Label Acceptance
# How to read:
# - Very low acceptance means unlabeled signal is weak.
# - Very high acceptance with low quality can be risky.

# %%
plt.figure(figsize=(6.2, 3.4))
plt.plot([r['round'] for r in st.history], [r['pseudo_label_fraction'] for r in st.history], marker='o', label='self-training accept')
plt.plot([r['epoch'] for r in mt.history], [r['pseudo_label_fraction'] for r in mt.history], marker='o', label='mean teacher accept')
plt.plot([r['epoch'] for r in hyb.history], [r['pseudo_label_fraction'] for r in hyb.history], marker='o', label='hybrid accept')
plt.title('Pseudo-label acceptance comparison')
plt.xlabel('step')
plt.ylabel('fraction')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Plot C: Pseudo-Label Accuracy

# %%
plt.figure(figsize=(6.2, 3.4))
plt.plot([r['round'] for r in st.history], [r['pseudo_label_accuracy'] for r in st.history], marker='o', label='self-training pseudo acc')
plt.plot([r['epoch'] for r in mt.history], [r['pseudo_label_accuracy'] for r in mt.history], marker='o', label='mean teacher pseudo acc')
plt.plot([r['epoch'] for r in hyb.history], [r['pseudo_label_accuracy'] for r in hyb.history], marker='o', label='hybrid pseudo acc')
plt.title('Pseudo-label accuracy comparison')
plt.xlabel('step')
plt.ylabel('accuracy')
plt.ylim(0, 1)
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ## Key Takeaways
# - Hybrid is designed to combine stability and selective trust.
# - Comparing acceptance and pseudo-label quality together explains behavior better than accuracy alone.

# %% [markdown]
# ## Failure Modes
# - Bad threshold/warm-up settings can remove hybrid benefits.
# - Method comparison is sensitive to seed and split.
