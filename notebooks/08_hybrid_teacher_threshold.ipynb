# %% [markdown]
# # 08 Hybrid Teacher + Threshold
#
# ## Concept
# Hybrid combines teacher smoothing and confidence thresholding.

# %% [markdown]
# ## Why This Method Exists
# It targets two failure sources together: volatile targets and noisy acceptance.

# %% [markdown]
# ## Algorithm Intuition
# - Teacher reduces target variance.
# - Threshold filters low-confidence pseudo-labels.
# - Together they aim for safer recursive updates.

# %% [markdown]
# ## Minimal Implementation

# %%
from pathlib import Path
import sys
import torch
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent / 'src'))

from utils.seed import set_seed
from data.mnist import get_mnist_ssl_twoview
from data.cifar10 import get_cifar10_ssl_twoview
from models.small_cnn import SmallCNN
from models.resnet18 import build_resnet18
from methods.self_training import run_self_training
from methods.mean_teacher import run_mean_teacher
from methods.hybrid_teacher_threshold import run_hybrid

# %% [markdown]
# ## Experiment
# Compare self-training, Mean Teacher, and Hybrid on the same split.

# %%
set_seed(42)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FAST_DEV_RUN = True

if FAST_DEV_RUN:
    loaders = get_mnist_ssl_twoview('data', labeled_per_class=50, batch_size=128, num_workers=2, seed=42)
    build = SmallCNN
    epochs = 4
    rounds = 4
    tau = 0.95
    lambda_u = 1.0
    ema_decay = 0.99
else:
    loaders = get_cifar10_ssl_twoview('data', labeled_per_class=40, batch_size=128, num_workers=2, seed=42)
    build = build_resnet18
    epochs = 20
    rounds = 4
    tau = 0.95
    lambda_u = 10.0
    ema_decay = 0.999

config = {
    'fast_dev_run': FAST_DEV_RUN,
    'epochs': epochs,
    'rounds': rounds,
    'tau': tau,
    'lambda_u': lambda_u,
    'ema_decay': ema_decay,
}
print(config)
print({'device': str(DEVICE), 'num_labeled': len(loaders.labeled.dataset), 'num_unlabeled': len(loaders.unlabeled.dataset)})

# Self-training
st_model = build()
st_opt = torch.optim.SGD(st_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
st = run_self_training(
    st_model,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    st_opt,
    DEVICE,
    rounds=rounds,
    threshold=tau,
    use_soft=False,
    max_unlabeled_per_round=10000,
    use_progress=True,
)

# Mean Teacher
mt_student = build()
mt_teacher = build()
mt_opt = torch.optim.SGD(mt_student.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
mt = run_mean_teacher(
    mt_student,
    mt_teacher,
    loaders.labeled,
    loaders.unlabeled,
    loaders.test,
    mt_opt,
    DEVICE,
    epochs=epochs,
    ema_decay=ema_decay,
    lambda_u=lambda_u,
    unlabeled_eval=loaders.unlabeled_eval,
    pseudo_threshold=tau,
    warmup_epochs=max(1, epochs // 4),
    use_progress=True,
)

# Hybrid
hy_student = build()
hy_teacher = build()
hy_opt = torch.optim.SGD(hy_student.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
hyb = run_hybrid(
    hy_student,
    hy_teacher,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    hy_opt,
    DEVICE,
    epochs=epochs,
    ema_decay=ema_decay,
    tau=tau,
    lambda_u=lambda_u,
    tau_start=0.7,
    rampup_epochs=max(1, epochs // 4),
    use_progress=True,
)

# %% [markdown]
# ## Diagnostics

# %%
plt.figure(figsize=(5.7, 3.3))
plt.plot([r['round'] for r in st.history], [r['val_accuracy'] for r in st.history], marker='o', label='self-training')
plt.plot([r['epoch'] for r in mt.history], [r['val_accuracy'] for r in mt.history], marker='o', label='mean teacher')
plt.plot([r['epoch'] for r in hyb.history], [r['val_accuracy'] for r in hyb.history], marker='o', label='hybrid')
plt.title('Accuracy comparison')
plt.xlabel('step')
plt.ylabel('accuracy')
plt.ylim(0, 1)
plt.legend(frameon=False)
plt.tight_layout()

# %%
plt.figure(figsize=(5.7, 3.3))
plt.plot([r['round'] for r in st.history], [r['pseudo_label_fraction'] for r in st.history], marker='o', label='self-training accept')
plt.plot([r['epoch'] for r in mt.history], [r['pseudo_label_fraction'] for r in mt.history], marker='o', label='mean teacher accept')
plt.plot([r['epoch'] for r in hyb.history], [r['pseudo_label_fraction'] for r in hyb.history], marker='o', label='hybrid accept')
plt.title('Pseudo-label acceptance')
plt.xlabel('step')
plt.ylabel('fraction')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ## Key Takeaways
# - Hybrid should provide a stronger stability/usage tradeoff than pure self-training.
# - Comparing curves directly reveals stabilization effects.

# %% [markdown]
# ## Failure Modes
# - Poor threshold choice can negate the hybrid benefit.
# - If teacher lags too much, adaptation may slow down.
