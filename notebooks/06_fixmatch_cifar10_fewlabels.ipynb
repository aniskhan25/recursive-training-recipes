# %% [markdown]
# # 06 FixMatch-Style Pseudo-Labeling
#
# ## Concept
# FixMatch uses weak-view pseudo-labels and strong-view consistency training.

# %% [markdown]
# ## Why This Method Exists
# Naive self-training is unstable. FixMatch stabilizes recursion with thresholding and consistency.

# %% [markdown]
# ## Algorithm Intuition
# 1. Weak augment unlabeled image, predict class.
# 2. Keep only confident predictions (threshold).
# 3. Train on strong augment with that pseudo-label.

# %% [markdown]
# ## Minimal Implementation

# %%
from pathlib import Path
import sys
import torch
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent / 'src'))

from utils.seed import set_seed
from data.mnist import get_mnist_ssl_twoview
from data.cifar10 import get_cifar10_ssl
from models.small_cnn import SmallCNN
from models.resnet18 import build_resnet18
from methods.fixmatch import run_fixmatch

# %% [markdown]
# ## Experiment

# %%
set_seed(42)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FAST_DEV_RUN = False

if FAST_DEV_RUN:
    loaders = get_mnist_ssl_twoview('data', labeled_per_class=50, batch_size=128, num_workers=2, seed=42)
    model = SmallCNN()
    epochs = 3
    tau = 0.95
    tau_start = 0.7
    lambda_u = 1.0
    rampup_epochs = 2
else:
    loaders = get_cifar10_ssl('data', labeled_per_class=40, batch_size=128, num_workers=2, seed=42)
    model = build_resnet18()
    epochs = 20
    tau = 0.95
    tau_start = 0.7
    lambda_u = 10.0
    rampup_epochs = 5

config = {
    'fast_dev_run': FAST_DEV_RUN,
    'epochs': epochs,
    'tau': tau,
    'tau_start': tau_start,
    'lambda_u': lambda_u,
    'rampup_epochs': rampup_epochs,
}
print(config)
print({'device': str(DEVICE), 'num_labeled': len(loaders.labeled.dataset), 'num_unlabeled': len(loaders.unlabeled.dataset)})

optimizer = torch.optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)
result = run_fixmatch(
    model,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    optimizer,
    DEVICE,
    epochs=epochs,
    tau=tau,
    lambda_u=lambda_u,
    tau_start=tau_start,
    rampup_epochs=rampup_epochs,
    use_progress=True,
)

# %% [markdown]
# ## Diagnostics

# %%
# Visualize weak vs strong views from unlabeled loader
(u_w, u_s), _ = next(iter(loaders.unlabeled))

def to_img(x):
    x = x.detach().cpu()
    if x.ndim == 3 and x.shape[0] == 1:
        return x[0].numpy(), 'gray'
    return x.permute(1, 2, 0).numpy(), None

plt.figure(figsize=(6, 3))
for i in range(3):
    img_w, cmap_w = to_img(u_w[i])
    img_s, cmap_s = to_img(u_s[i])
    plt.subplot(2, 3, i + 1)
    plt.imshow(img_w, cmap=cmap_w)
    plt.axis('off')
    if i == 1:
        plt.title('weak')
    plt.subplot(2, 3, i + 4)
    plt.imshow(img_s, cmap=cmap_s)
    plt.axis('off')
    if i == 1:
        plt.title('strong')
plt.tight_layout()

# %%
plt.figure(figsize=(5.5, 3.2))
plt.plot([r['epoch'] for r in result.history], [r['val_accuracy'] for r in result.history], marker='o', label='val accuracy')
plt.plot([r['epoch'] for r in result.history], [r['unsupervised_loss'] for r in result.history], marker='o', label='unsup loss')
plt.title('FixMatch accuracy and unsupervised loss')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %%
plt.figure(figsize=(5.5, 3.2))
plt.plot([r['epoch'] for r in result.history], [r['pseudo_label_fraction'] for r in result.history], marker='o', label='accepted fraction')
plt.plot([r['epoch'] for r in result.history], [r['pseudo_label_accuracy'] for r in result.history], marker='o', label='pseudo-label accuracy')
plt.plot([r['epoch'] for r in result.history], [r['entropy'] for r in result.history], marker='o', label='entropy')
plt.title('FixMatch diagnostics')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ## Key Takeaways
# - Acceptance usually ramps up as confidence improves.
# - Quality of accepted pseudo-labels is the key indicator of SSL benefit.

# %% [markdown]
# ## Failure Modes
# - Too-low threshold accepts noisy labels.
# - Too-high threshold delays unlabeled learning.
# - Overconfident but wrong model can still drift.
