# %% [markdown]
# # 06 FixMatch-Style Pseudo-Labeling
#
# ## Concept
# FixMatch uses two views of each unlabeled image:
# - weak view for pseudo-label generation,
# - strong view for consistency training.

# %% [markdown]
# ## Why This Notebook Exists
# Naive self-training can amplify early mistakes.
# FixMatch stabilizes recursion using thresholded pseudo-labels and augmentation consistency.

# %% [markdown]
# ## Algorithm Intuition (One Loop)
# 1. Predict on weak view.
# 2. Keep only high-confidence predictions.
# 3. Train on strong view with those pseudo-labels.
# 4. Repeat.

# %% [markdown]
# ## Before You Run
# - `FAST_DEV_RUN=True` (default) uses MNIST and runs quickly.
# - `FAST_DEV_RUN=False` runs CIFAR-10 and is slower but closer to the target setting.

# %% [markdown]
# ## Step 1: Imports

# %%
from pathlib import Path
import sys
import torch
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent / 'src'))

from utils.seed import set_seed
from data.mnist import get_mnist_ssl_twoview
from data.cifar10 import get_cifar10_ssl
from models.small_cnn import SmallCNN
from models.resnet18 import build_resnet18
from methods.fixmatch import run_fixmatch
from methods.supervised import run_supervised

# %% [markdown]
# ## Step 2: Configuration
# Keep this printed for reproducibility.

# %%
set_seed(42)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FAST_DEV_RUN = True

if FAST_DEV_RUN:
    loaders = get_mnist_ssl_twoview('data', labeled_per_class=50, batch_size=128, num_workers=2, seed=42)
    model = SmallCNN()
    baseline_model = SmallCNN()
    epochs = 8
    tau = 0.95
    tau_start = 0.70
    lambda_u = 1.0
    rampup_epochs = 3
else:
    loaders = get_cifar10_ssl('data', labeled_per_class=40, batch_size=128, num_workers=2, seed=42)
    model = build_resnet18()
    baseline_model = build_resnet18()
    epochs = 20
    tau = 0.95
    tau_start = 0.70
    lambda_u = 10.0
    rampup_epochs = 5

config = {
    'fast_dev_run': FAST_DEV_RUN,
    'epochs': epochs,
    'tau': tau,
    'tau_start': tau_start,
    'lambda_u': lambda_u,
    'rampup_epochs': rampup_epochs,
}
print(config)
print({'device': str(DEVICE), 'num_labeled': len(loaders.labeled.dataset), 'num_unlabeled': len(loaders.unlabeled.dataset)})

# %% [markdown]
# ## Step 3: Visualize Weak vs Strong Views
# This is the key FixMatch design choice.

# %%
(u_w, u_s), _ = next(iter(loaders.unlabeled))

def to_img(x):
    x = x.detach().cpu()
    if x.ndim == 3 and x.shape[0] == 1:
        return x[0].numpy(), 'gray'
    return x.permute(1, 2, 0).numpy(), None

plt.figure(figsize=(6.5, 3.2))
for i in range(3):
    w_img, w_cmap = to_img(u_w[i])
    s_img, s_cmap = to_img(u_s[i])

    plt.subplot(2, 3, i + 1)
    plt.imshow(w_img, cmap=w_cmap)
    plt.axis('off')
    if i == 1:
        plt.title('Weak view')

    plt.subplot(2, 3, i + 4)
    plt.imshow(s_img, cmap=s_cmap)
    plt.axis('off')
    if i == 1:
        plt.title('Strong view')

plt.tight_layout()

# %% [markdown]
# ## Step 4: Train FixMatch

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

fix = run_fixmatch(
    model,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    optimizer,
    DEVICE,
    epochs=epochs,
    tau=tau,
    lambda_u=lambda_u,
    tau_start=tau_start,
    rampup_epochs=rampup_epochs,
    use_progress=True,
)

# %% [markdown]
# ## Step 5: Train Supervised Baseline
# This gives a direct comparison against "no SSL".

# %%
baseline_opt = torch.optim.SGD(baseline_model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

baseline = run_supervised(
    baseline_model,
    loaders.labeled,
    loaders.test,
    baseline_opt,
    DEVICE,
    epochs=epochs,
    use_progress=True,
)

# %% [markdown]
# ## Step 6: Final Snapshot
# Read this before looking at the curves.

# %%
fix_last = fix.history[-1]
base_last = baseline.history[-1]
summary = {
    'baseline_val_accuracy': base_last['val_accuracy'],
    'fixmatch_val_accuracy': fix_last['val_accuracy'],
    'accuracy_delta_fix_minus_base': fix_last['val_accuracy'] - base_last['val_accuracy'],
    'pseudo_label_fraction': fix_last['pseudo_label_fraction'],
    'pseudo_label_accuracy': fix_last['pseudo_label_accuracy'],
    'mean_confidence': fix_last['mean_confidence'],
    'entropy': fix_last['entropy'],
}
summary

# %% [markdown]
# ## Step 7: Diagnostics
# ### Plot A: Accuracy (FixMatch vs Baseline)
# How to read:
# - positive gap indicates SSL benefit,
# - small/zero gap can still be valid in non-label-starved regimes.

# %%
plt.figure(figsize=(6.0, 3.3))
plt.plot([r['epoch'] for r in baseline.history], [r['val_accuracy'] for r in baseline.history], marker='o', linestyle='--', label='supervised baseline')
plt.plot([r['epoch'] for r in fix.history], [r['val_accuracy'] for r in fix.history], marker='o', label='FixMatch')
plt.title('Validation accuracy comparison')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.ylim(0, 1)
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Plot B: Optimization Signals
# Separate scale from accuracy so trends are readable.

# %%
plt.figure(figsize=(6.0, 3.3))
plt.plot([r['epoch'] for r in fix.history], [r['unsupervised_loss'] for r in fix.history], marker='o', label='unsupervised loss')
plt.plot([r['epoch'] for r in fix.history], [r['pseudo_label_fraction'] for r in fix.history], marker='o', label='accepted fraction')
plt.title('FixMatch optimization signals')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Plot C: Pseudo-Label Quality
# How to read:
# - quality should rise as acceptance becomes meaningful,
# - entropy often decreases as predictions sharpen.

# %%
plt.figure(figsize=(6.0, 3.3))
plt.plot([r['epoch'] for r in fix.history], [r['pseudo_label_accuracy'] for r in fix.history], marker='o', label='pseudo-label accuracy')
plt.plot([r['epoch'] for r in fix.history], [r['entropy'] for r in fix.history], marker='o', label='entropy')
plt.title('Pseudo-label diagnostics')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ## Expected Observations And Interpretation
# Expected reproducible pattern in this setup:
# - early epochs may show low acceptance as thresholding gates noisy pseudo-labels,
# - pseudo-label quality should improve before strong SSL gains appear,
# - FixMatch may match or slightly exceed baseline; large gains are not guaranteed in less label-starved regimes.
#
# Interpretation rule:
# judge FixMatch using **accuracy gap + pseudo-label quality + acceptance trend**, not final accuracy alone.

# %% [markdown]
# ## Key Takeaways
# - FixMatch stabilizes recursive learning with selective trust and consistency.
# - Healthy behavior means acceptance and pseudo-label quality improve together.

# %% [markdown]
# ## Failure Modes
# - Too-low threshold: noisy pseudo-labels flood training.
# - Too-high threshold: SSL stays mostly inactive.
# - High confidence alone is not enough; calibration still matters.
