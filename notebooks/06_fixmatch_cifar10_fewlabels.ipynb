# %% [markdown]
# # 06 FixMatch-Style Pseudo-Labeling
#
# ## Concept
# FixMatch uses two views of the same unlabeled image:
# - **weak view** to make a pseudo-label
# - **strong view** to train consistency

# %% [markdown]
# ## Why This Method Exists
# Naive self-training can amplify early mistakes.
# FixMatch adds two stabilizers:
# 1. confidence threshold
# 2. strong-augmentation consistency

# %% [markdown]
# ## Algorithm Intuition (One Loop)
# 1. Predict on weak view.
# 2. Keep only high-confidence predictions.
# 3. Train on strong view using those pseudo-labels.
# 4. Repeat.

# %% [markdown]
# ## Before You Run
# - `FAST_DEV_RUN=True` uses MNIST for quick learning.
# - Set `FAST_DEV_RUN=False` for CIFAR-10 (slower, more realistic).

# %% [markdown]
# ## Step 1: Imports

# %%
from pathlib import Path
import sys
import torch
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent / 'src'))

from utils.seed import set_seed
from data.mnist import get_mnist_ssl_twoview
from data.cifar10 import get_cifar10_ssl
from models.small_cnn import SmallCNN
from models.resnet18 import build_resnet18
from methods.fixmatch import run_fixmatch

# %% [markdown]
# ## Step 2: Configuration
# Keep this visible so you always know what experiment you are running.

# %%
set_seed(42)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
FAST_DEV_RUN = True

if FAST_DEV_RUN:
    loaders = get_mnist_ssl_twoview('data', labeled_per_class=50, batch_size=128, num_workers=2, seed=42)
    model = SmallCNN()
    epochs = 5
    tau = 0.95
    tau_start = 0.70
    lambda_u = 1.0
    rampup_epochs = 2
else:
    loaders = get_cifar10_ssl('data', labeled_per_class=40, batch_size=128, num_workers=2, seed=42)
    model = build_resnet18()
    epochs = 20
    tau = 0.95
    tau_start = 0.70
    lambda_u = 10.0
    rampup_epochs = 5

config = {
    'fast_dev_run': FAST_DEV_RUN,
    'epochs': epochs,
    'tau': tau,
    'tau_start': tau_start,
    'lambda_u': lambda_u,
    'rampup_epochs': rampup_epochs,
}
print(config)
print({'device': str(DEVICE), 'num_labeled': len(loaders.labeled.dataset), 'num_unlabeled': len(loaders.unlabeled.dataset)})

# %% [markdown]
# ## Step 3: Visualize Weak vs Strong Views
# This is the most important FixMatch idea.
# If weak and strong look too similar, the consistency signal is weak.

# %%
(u_w, u_s), _ = next(iter(loaders.unlabeled))

def to_img(x):
    x = x.detach().cpu()
    if x.ndim == 3 and x.shape[0] == 1:
        return x[0].numpy(), 'gray'
    return x.permute(1, 2, 0).numpy(), None

plt.figure(figsize=(6.5, 3.2))
for i in range(3):
    w_img, w_cmap = to_img(u_w[i])
    s_img, s_cmap = to_img(u_s[i])

    plt.subplot(2, 3, i + 1)
    plt.imshow(w_img, cmap=w_cmap)
    plt.axis('off')
    if i == 1:
        plt.title('Weak view')

    plt.subplot(2, 3, i + 4)
    plt.imshow(s_img, cmap=s_cmap)
    plt.axis('off')
    if i == 1:
        plt.title('Strong view')

plt.tight_layout()

# %% [markdown]
# ## Step 4: Train

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4)

result = run_fixmatch(
    model,
    loaders.labeled,
    loaders.unlabeled,
    loaders.unlabeled_eval,
    loaders.test,
    optimizer,
    DEVICE,
    epochs=epochs,
    tau=tau,
    lambda_u=lambda_u,
    tau_start=tau_start,
    rampup_epochs=rampup_epochs,
    use_progress=True,
)

# %% [markdown]
# ## Step 5: Final Snapshot
# Read this quick summary before looking at curves.

# %%
last = result.history[-1]
summary = {
    'val_accuracy': last['val_accuracy'],
    'pseudo_label_fraction': last['pseudo_label_fraction'],
    'pseudo_label_accuracy': last['pseudo_label_accuracy'],
    'mean_confidence': last['mean_confidence'],
    'entropy': last['entropy'],
}
summary

# %% [markdown]
# ## Step 6: Diagnostics
# ### Plot A: Accuracy and Unsupervised Loss
# How to read:
# - accuracy should generally rise
# - unsupervised loss should become more stable over time

# %%
plt.figure(figsize=(6, 3.3))
plt.plot([r['epoch'] for r in result.history], [r['val_accuracy'] for r in result.history], marker='o', label='val accuracy')
plt.plot([r['epoch'] for r in result.history], [r['unsupervised_loss'] for r in result.history], marker='o', label='unsup loss')
plt.title('FixMatch: accuracy and unsupervised loss')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Plot B: Pseudo-Label Quality
# How to read:
# - `pseudo_label_fraction` = how much unlabeled data is used
# - `pseudo_label_accuracy` = quality of accepted pseudo-labels
# - `entropy` = overall certainty (lower usually means sharper predictions)

# %%
plt.figure(figsize=(6, 3.3))
plt.plot([r['epoch'] for r in result.history], [r['pseudo_label_fraction'] for r in result.history], marker='o', label='accepted fraction')
plt.plot([r['epoch'] for r in result.history], [r['pseudo_label_accuracy'] for r in result.history], marker='o', label='pseudo-label accuracy')
plt.plot([r['epoch'] for r in result.history], [r['entropy'] for r in result.history], marker='o', label='entropy')
plt.title('FixMatch: pseudo-label diagnostics')
plt.xlabel('epoch')
plt.ylabel('value')
plt.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ## Key Takeaways
# - FixMatch makes pseudo-labeling safer using threshold + strong augmentation.
# - Good SSL behavior means **acceptance and pseudo-label quality improve together**.

# %% [markdown]
# ## Failure Modes
# - Too-low threshold: noisy pseudo-labels flood training.
# - Too-high threshold: little unlabeled data is used.
# - High confidence does not guarantee correctness.
